# %%
import pandas as pd

# %%
df=pd.read_csv('games.csv')

# %%
df.head()
# Out:
#    game_id        game_name      author  \
# 0   160388  Petal Quest 1.2    noelcody
# 1   109978             loop     kreyk29
# 2   171379    Crimson Night  Fictionity
# 3   149934      Up And Away       rmcco
# 4   148521        ghostwave       Conor
#
#                                          artwork_url  \
# 0  https://www.lexaloffle.com/bbs/thumbs/pico8_pe...
# 1  https://www.lexaloffle.com/bbs/thumbs/pico8_lo...
# 2  https://www.lexaloffle.com/bbs/thumbs/pico8_cr...
# 3  https://www.lexaloffle.com/bbs/thumbs/pico8_up...
# 4  https://www.lexaloffle.com/bbs/thumbs/pico8_gh...
#
#                                artwork_path  \
# 0  data/raw/artwork/001_Petal_Quest_1.2.png
# 1             data/raw/artwork/002_loop.png
# 2    data/raw/artwork/003_Crimson_Night.png
# 3      data/raw/artwork/004_Up_And_Away.png
# 4        data/raw/artwork/005_ghostwave.png
#
#                                             cart_url  \
# 0  https://www.lexaloffle.com/bbs/cposts/pe/petal...
# ...
